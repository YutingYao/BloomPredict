# %% [markdown]
# 但现在我们需要制作了一个新的csv：df = pd.read_csv('/root/Download/AlgaeBloomForecast/merged_data.csv')
#
# ```
# date,temp,oxygen,NH3,TP,TN,algae,area,weather,max_temperature,min_temperature,aqi,aqiLevel,wind_direction,wind_power,aqiInfo
# 2021-06-02,26.1875,6.6665,0.025,0.068275,1.07325,14400000.0,无锡,阴-阵雨,26,21,24,1,东南风,4级,优
# 2021-06-03,25.881666666666664,6.6418333333333335,0.0251166666666666,0.0637833333333333,0.9151666666666666,10867091.666666666,无锡,阴-阵雨,26,19,66,2,西北风,3级,良
# 2021-06-04,25.895,7.946333333333333,0.025,0.0637833333333333,0.9203333333333332,25498423.33333333,无锡,阴-多云,26,18,51,2,西南风,3级,良
# 2021-06-05,26.85,9.084,0.025,0.04776,0.9058,21100000.0,无锡,晴,32,19,67,2,西南风,3级,良
# 2021-06-06,28.256666666666664,9.514333333333331,0.025,0.0440666666666666,0.9233333333333332,15211340.0,无锡,晴,33,19,80,2,南风,3级,良
# 2021-06-07,27.635,8.3865,0.025,0.0366499999999999,0.7778333333333333,7994458.333333333,无锡,阴-多云,35,21,68,2,东南风,3级,良
# 2021-06-08,28.19666666666667,8.397499999999999,0.025,0.0418666666666666,0.7323333333333334,12259158.333333334,无锡,阴-多云,30,24,36,1,东南风,3级,优
# 2021-06-09,28.751666666666665,8.309166666666668,0.025,0.0389833333333333,0.601,6891956.666666667,无锡,阴-雷阵雨,32,24,52,2,东南风,3级,良
# 2021-06-10,28.741666666666664,7.385833333333333,0.025,0.03785,0.5256666666666666,6301236.666666667,无锡,阴,28,24,38,1,东南风,2级,优
# 2021-06-11,29.491666666666664,7.6176666666666675,0.025,0.0327666666666666,0.4495,6244151.666666667,无锡,阴-多云,32,23,82,2,东风,2级,良
# 2021-06-12,29.58666666666667,7.271999999999999,0.025,0.02975,0.3741666666666667,4201731.666666667,无锡,多云-雷阵雨,33,24,41,1,东南风,3级,优
# 2021-06-13,29.563333333333333,6.929333333333333,0.025,0.0302833333333333,0.2663333333333333,4964940.0,无锡,阴-小雨,28,25,34,1,西南风,2级,优
# 2021-06-14,29.58833333333333,6.963166666666666,0.025,0.0290666666666666,0.1886666666666666,5394340.0,无锡,阴-小雨,31,25,46,1,东南风,3级,优
# 2021-06-15,30.21,7.23925,0.025,0.033425,0.396,6927237.5,无锡,阴-小雨,33,24,48,1,西南风,3级,优
# ```
#
# 这里我们要用GRU预测藻类的爆发，来捕获时间序列数据的长距离依赖关系。这里提供了逐日的数据，需要考虑date的影响。
#
# 通过前期的数据分析，我们发现：
# - 这里需要考虑['temp', 'oxygen', 'NH3', 'TP', 'TN']对'algae'的影响
# - 这里需要考虑weather这一列出现“晴”的影响，以及“晴”的长距离依赖关系。
# - 温度的影响，这里，只采用temp作为特征，考虑温度的长距离依赖关系。
# - 不考虑max_temperature,min_temperature。
# - wind_power大于4级时是一个需要考虑的因素，考虑wind_power的长距离依赖关系。
# - 这里的aqi,aqiLevel，aqiInfo与空气质量相关，不考虑。
# - wind_direction也不考虑。
#
# 请你输出完整的代码。需要：
# - 做归一化的处理
# - 需要对数据分割，将最近180天的结果作为测试集。
# - 需要绘制训练过程的图片、需要输出预测效果的图片，它将生成两个图像文件：`training_loss_GRU.png`显示训练过程，`prediction_results_GRU.png`显示预测效果
# - 模型的训练参数是可调整的，比如，添加了学习率调度（ReduceLROnPlateau）、在优化器中添加了L2正则化（weight_decay）、调整了模型结构，包括隐藏层维度和dropout率。

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# 读取数据
df = pd.read_csv('/root/Download/AlgaeBloomForecast/merged_data.csv')

# 数据预处理
df['date'] = pd.to_datetime(df['date'])
df['is_sunny'] = df['weather'].str.contains('晴').astype(int)
df['wind_power_high'] = (df['wind_power'].str.extract('(\d+)').astype(float) > 4).astype(int)

# 选择特征
features = ['temp', 'oxygen', 'NH3', 'TP', 'TN', 'is_sunny', 'wind_power_high']
target = 'algae'

# 归一化
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X = scaler_X.fit_transform(df[features])
y = scaler_y.fit_transform(df[[target]])

# 创建时间窗口数据
def create_sequences(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps)])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 7  # 使用过去7天的数据来预测下一天
X_seq, y_seq = create_sequences(X, y, time_steps)

# 分割数据集
train_size = len(X_seq) - 180  # 最后180天作为测试集
X_train, X_test = X_seq[:train_size], X_seq[train_size:]
y_train, y_test = y_seq[:train_size], y_seq[train_size:]

# 转换为PyTorch张量
X_train = torch.FloatTensor(X_train)
y_train = torch.FloatTensor(y_train)
X_test = torch.FloatTensor(X_test)
y_test = torch.FloatTensor(y_test)

# 创建数据加载器
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# 定义GRU模型
class GRUModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim, dropout_prob):
        super(GRUModel, self).__init__()
        self.hidden_dim = hidden_dim
        self.layer_dim = layer_dim
        self.gru = nn.GRU(input_dim, hidden_dim, layer_dim, batch_first=True, dropout=dropout_prob)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).requires_grad_().to(x.device)
        out, _ = self.gru(x, h0.detach())
        out = self.fc(out[:, -1, :])
        return out

# 初始化模型
input_dim = len(features)
hidden_dim = 64
layer_dim = 2
output_dim = 1
dropout_prob = 0.2

model = GRUModel(input_dim, hidden_dim, layer_dim, output_dim, dropout_prob)

# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

# 学习率调度器
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

# 训练模型
num_epochs = 100
train_losses = []
test_losses = []

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            y_pred = model(X_batch)
            loss = criterion(y_pred, y_batch)
            test_loss += loss.item()
    
    test_loss /= len(test_loader)
    test_losses.append(test_loss)
    
    scheduler.step(test_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}')

# 绘制训练过程
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Testing Loss')
plt.legend()
plt.savefig('training_loss_GRU.png')
plt.close()

# 预测
model.eval()
with torch.no_grad():
    y_pred = model(X_test).numpy()

# 反归一化
y_pred = scaler_y.inverse_transform(y_pred)
y_test = scaler_y.inverse_transform(y_test)

# 绘制预测结果
plt.figure(figsize=(12, 6))
plt.plot(df['date'].iloc[-180:], y_test, label='Actual')
plt.plot(df['date'].iloc[-180:], y_pred, label='Predicted')
plt.xlabel('Date')
plt.ylabel('Algae Bloom')
plt.title('Algae Bloom Prediction')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('prediction_results_GRU.png')
plt.close()

# 计算预测性能指标
mse = np.mean((y_test - y_pred)**2)
rmse = np.sqrt(mse)
mae = np.mean(np.abs(y_test - y_pred))
r2 = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - np.mean(y_test))**2))

print(f'Mean Squared Error: {mse:.4f}')
print(f'Root Mean Squared Error: {rmse:.4f}')
print(f'Mean Absolute Error: {mae:.4f}')
print(f'R-squared: {r2:.4f}')
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\d'
# <>:17: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_28155/1443398383.py:17: SyntaxWarning: invalid escape sequence '\d'
#   df['wind_power_high'] = (df['wind_power'].str.extract('(\d+)').astype(float) > 4).astype(int)
# /root/.conda/envs/hydro/envs/algae/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/100], Train Loss: 0.0191, Test Loss: 0.0158
# Epoch [2/100], Train Loss: 0.0163, Test Loss: 0.0180
# Epoch [3/100], Train Loss: 0.0173, Test Loss: 0.0191
# Epoch [4/100], Train Loss: 0.0159, Test Loss: 0.0164
# Epoch [5/100], Train Loss: 0.0160, Test Loss: 0.0206
# Epoch [6/100], Train Loss: 0.0161, Test Loss: 0.0170
# Epoch [7/100], Train Loss: 0.0158, Test Loss: 0.0165
# Epoch [8/100], Train Loss: 0.0155, Test Loss: 0.0178
# Epoch [9/100], Train Loss: 0.0169, Test Loss: 0.0155
# Epoch [10/100], Train Loss: 0.0160, Test Loss: 0.0204
# Epoch [11/100], Train Loss: 0.0158, Test Loss: 0.0187
# Epoch [12/100], Train Loss: 0.0150, Test Loss: 0.0163
# Epoch [13/100], Train Loss: 0.0150, Test Loss: 0.0170
# Epoch [14/100], Train Loss: 0.0155, Test Loss: 0.0157
# Epoch [15/100], Train Loss: 0.0159, Test Loss: 0.0208
# Epoch [16/100], Train Loss: 0.0154, Test Loss: 0.0168
# Epoch [17/100], Train Loss: 0.0149, Test Loss: 0.0167
# Epoch [18/100], Train Loss: 0.0151, Test Loss: 0.0156
# Epoch [19/100], Train Loss: 0.0153, Test Loss: 0.0161
# Epoch [20/100], Train Loss: 0.0147, Test Loss: 0.0146
# Epoch [21/100], Train Loss: 0.0147, Test Loss: 0.0167
# Epoch [22/100], Train Loss: 0.0141, Test Loss: 0.0182
# Epoch [23/100], Train Loss: 0.0145, Test Loss: 0.0141
# Epoch [24/100], Train Loss: 0.0141, Test Loss: 0.0118
# Epoch [25/100], Train Loss: 0.0142, Test Loss: 0.0139
# Epoch [26/100], Train Loss: 0.0136, Test Loss: 0.0126
# Epoch [27/100], Train Loss: 0.0128, Test Loss: 0.0111
# Epoch [28/100], Train Loss: 0.0133, Test Loss: 0.0185
# Epoch [29/100], Train Loss: 0.0135, Test Loss: 0.0152
# Epoch [30/100], Train Loss: 0.0125, Test Loss: 0.0147
# Epoch [31/100], Train Loss: 0.0115, Test Loss: 0.0130
# Epoch [32/100], Train Loss: 0.0118, Test Loss: 0.0144
# Epoch [33/100], Train Loss: 0.0129, Test Loss: 0.0145
# Epoch [34/100], Train Loss: 0.0145, Test Loss: 0.0169
# Epoch [35/100], Train Loss: 0.0136, Test Loss: 0.0194
# Epoch [36/100], Train Loss: 0.0129, Test Loss: 0.0149
# Epoch [37/100], Train Loss: 0.0114, Test Loss: 0.0164
# Epoch [38/100], Train Loss: 0.0116, Test Loss: 0.0147
# Epoch [39/100], Train Loss: 0.0099, Test Loss: 0.0155
# Epoch [40/100], Train Loss: 0.0094, Test Loss: 0.0148
# Epoch [41/100], Train Loss: 0.0105, Test Loss: 0.0149
# Epoch [42/100], Train Loss: 0.0105, Test Loss: 0.0147
# Epoch [43/100], Train Loss: 0.0098, Test Loss: 0.0148
# Epoch [44/100], Train Loss: 0.0098, Test Loss: 0.0146
# Epoch [45/100], Train Loss: 0.0099, Test Loss: 0.0147
# Epoch [46/100], Train Loss: 0.0090, Test Loss: 0.0144
# Epoch [47/100], Train Loss: 0.0100, Test Loss: 0.0146
# Epoch [48/100], Train Loss: 0.0097, Test Loss: 0.0151
# Epoch [49/100], Train Loss: 0.0102, Test Loss: 0.0143
# Epoch [50/100], Train Loss: 0.0092, Test Loss: 0.0144
# Epoch [51/100], Train Loss: 0.0091, Test Loss: 0.0145
# Epoch [52/100], Train Loss: 0.0094, Test Loss: 0.0146
# Epoch [53/100], Train Loss: 0.0105, Test Loss: 0.0147
# Epoch [54/100], Train Loss: 0.0101, Test Loss: 0.0148
# Epoch [55/100], Train Loss: 0.0097, Test Loss: 0.0148
# Epoch [56/100], Train Loss: 0.0094, Test Loss: 0.0148
# Epoch [57/100], Train Loss: 0.0099, Test Loss: 0.0147
# Epoch [58/100], Train Loss: 0.0088, Test Loss: 0.0148
# Epoch [59/100], Train Loss: 0.0090, Test Loss: 0.0148
# Epoch [60/100], Train Loss: 0.0093, Test Loss: 0.0148
# Epoch [61/100], Train Loss: 0.0090, Test Loss: 0.0148
# Epoch [62/100], Train Loss: 0.0090, Test Loss: 0.0148
# Epoch [63/100], Train Loss: 0.0093, Test Loss: 0.0148
# Epoch [64/100], Train Loss: 0.0095, Test Loss: 0.0148
# Epoch [65/100], Train Loss: 0.0090, Test Loss: 0.0148
# Epoch [66/100], Train Loss: 0.0094, Test Loss: 0.0148
# Epoch [67/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [68/100], Train Loss: 0.0093, Test Loss: 0.0148
# Epoch [69/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [70/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [71/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [72/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [73/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [74/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [75/100], Train Loss: 0.0090, Test Loss: 0.0148
# Epoch [76/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [77/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [78/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [79/100], Train Loss: 0.0094, Test Loss: 0.0148
# Epoch [80/100], Train Loss: 0.0099, Test Loss: 0.0148
# Epoch [81/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [82/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [83/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [84/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [85/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [86/100], Train Loss: 0.0094, Test Loss: 0.0148
# Epoch [87/100], Train Loss: 0.0094, Test Loss: 0.0148
# Epoch [88/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [89/100], Train Loss: 0.0090, Test Loss: 0.0148
# Epoch [90/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [91/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [92/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [93/100], Train Loss: 0.0089, Test Loss: 0.0148
# Epoch [94/100], Train Loss: 0.0092, Test Loss: 0.0148
# Epoch [95/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [96/100], Train Loss: 0.0090, Test Loss: 0.0148
# Epoch [97/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [98/100], Train Loss: 0.0095, Test Loss: 0.0148
# Epoch [99/100], Train Loss: 0.0091, Test Loss: 0.0148
# Epoch [100/100], Train Loss: 0.0093, Test Loss: 0.0148
# Mean Squared Error: 967400743824950.7500
# Root Mean Squared Error: 31103066.4698
# Mean Absolute Error: 20334798.3043
# R-squared: -0.0831
